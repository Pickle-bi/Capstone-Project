# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\kweku Bediako\\Downloads\\Customer-Churn.csv")

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data = data.drop(["customerID"] , axis = 1)

# %%
data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
data.describe().T
# Out:
#                  count       mean        std    min   25%    50%    75%  \
# SeniorCitizen   7043.0   0.162147   0.368612   0.00   0.0   0.00   0.00
# tenure          7043.0  32.371149  24.559481   0.00   9.0  29.00  55.00
# MonthlyCharges  7043.0  64.761692  30.090047  18.25  35.5  70.35  89.85
#
#                    max
# SeniorCitizen     1.00
# tenure           72.00
# MonthlyCharges  118.75

# %%
data.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
plt.figure(figsize =(10,5))
sns.heatmap(data = data.isnull(), cmap = "viridis", vmin = 0, vmax = 1)
plt.xticks(rotation =45)
plt.show();

# %% [markdown]
# # NUMERICAL DATA

# %%
numerical_df = data.select_dtypes(exclude = "object")

# %%
numerical_df.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges
# 0              0       1           29.85
# 1              0      34           56.95
# 2              0       2           53.85
# 3              0      45           42.30
# 4              0       2           70.70

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
plt.figure(figsize = (10 , 5))
sns.histplot(data = data["SeniorCitizen"], bins = 20)
plt.title("Distribution of SeniorCitizen")
plt.ylabel("Frequency")
# Out:
# C:\Users\kweku Bediako\Downloads\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'Frequency')

# %%
numerical_df.head(1)
# Out:
#    SeniorCitizen  tenure  MonthlyCharges
# 0              0       1           29.85

# %%
numerical_cols = numerical_df.columns.to_list()

# %% [markdown]
# # Distibution of numerical features

# %%
def plot_features(n_features, n_cols, n_rows):
    n_features =len(numerical_cols)
    num_cols = 2
    num_rows = (n_features + 1)//num_cols
    fig , axes = plt.subplots(nrows = 2 , ncols =5, figsize = (20,5))

# %%
n_features =len(numerical_cols)
num_cols = 2
num_rows = (n_features + 1)//num_cols

fig, axes = plt.subplots(ncols= num_cols, nrows = num_rows, figsize = (20,10))

position = axes.flatten()

for index, feature in enumerate(numerical_cols):
    sns.histplot(data = data[feature], ax = position[index])
# Out:
# C:\Users\kweku Bediako\Downloads\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\kweku Bediako\Downloads\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\kweku Bediako\Downloads\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # BI VARIATE ANALYSIS

# %%
data.corr(numeric_only = True)
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.016567        0.220173
# tenure               0.016567  1.000000        0.247900
# MonthlyCharges       0.220173  0.247900        1.000000

# %%
numerical_df.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.016567        0.220173
# tenure               0.016567  1.000000        0.247900
# MonthlyCharges       0.220173  0.247900        1.000000

# %%
my_mask = np.triu(np.ones_like(numerical_df.corr(), dtype = bool))

plt.figure(figsize = (10,6))
sns.heatmap(data = numerical_df.corr(), cmap = "viridis" , vmin = -1, vmax = 1 , fmt = ".2f" , annot = True, mask = my_mask)
# Out:
# C:\Users\kweku Bediako\Downloads\New folder\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# <Axes: >

# %% [markdown]
# # CATEGORICAL DATA

# %%
categorical_df = data.select_dtypes(include = "object")

# %%
categorical_df.head(2)
# Out:
#    gender Partner Dependents PhoneService     MultipleLines InternetService  \
# 0  Female     Yes         No           No  No phone service             DSL
# 1    Male      No         No          Yes                No             DSL
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No          No          No
# 1            Yes           No              Yes          No          No
#
#   StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# 0              No  Month-to-month              Yes  Electronic check
# 1              No        One year               No      Mailed check
#
#   TotalCharges Churn
# 0        29.85    No
# 1       1889.5    No

# %%
cat_columns = categorical_df.columns.to_list()

# %%
for feature in cat_columns:
    print(f"{feature} >>>> {data[feature].nunique()}")
# Out:
# gender >>>> 2
# Partner >>>> 2
# Dependents >>>> 2
# PhoneService >>>> 2
# MultipleLines >>>> 3
# InternetService >>>> 3
# OnlineSecurity >>>> 3
# OnlineBackup >>>> 3
# DeviceProtection >>>> 3
# TechSupport >>>> 3
# StreamingTV >>>> 3
# StreamingMovies >>>> 3
# Contract >>>> 3
# PaperlessBilling >>>> 2
# PaymentMethod >>>> 4
# TotalCharges >>>> 6531
# Churn >>>> 2

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
fig, axes = plt.subplots(nrows=6, ncols=3, figsize=(12,10))

position = axes.flatten()

for index, feature in enumerate(cat_columns):
    sns.barplot(x = data[feature].value_counts().index, y = data[feature].value_counts().values, ax = position[index]) 

plt.tight_layout()

# %% [markdown]
# # BI-VARIATE ANALYSIS

# %%
fig, axes = plt.subplots(nrows = 4, ncols = 4, figsize = (20,15))

position = axes.flatten()

for index, feature in enumerate(cat_columns):
    sns.countplot(data = categorical_df, x= feature, hue = data["Churn"], ax = position[index])
    

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 6
#       3 position = axes.flatten()
#       5 for index, feature in enumerate(cat_columns):
# ----> 6     sns.countplot(data = categorical_df, x= feature, hue = data["Churn"], ax = position[index])
#       9 plt.tight_layout()
#
# IndexError: index 16 is out of bounds for axis 0 with size 16

# %%
sns.barplot(data= data, x= data["Churn"].value_counts().index, y = data["Churn"].value_counts().values)
# Out:
# <Axes: xlabel='Churn'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
labels = data['Churn']
features = data.drop(['Churn'], axis=1)

# %%
labels
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7043, dtype: object

# %%
features.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
data = data.drop(["Churn"] , axis = 1)

# %%
all_categorical_columns = data.select_dtypes(include = "object")

# %%
all_categorical_columns.head()
# Out:
#    gender Partner Dependents PhoneService     MultipleLines InternetService  \
# 0  Female     Yes         No           No  No phone service             DSL
# 1    Male      No         No          Yes                No             DSL
# 2    Male      No         No          Yes                No             DSL
# 3    Male      No         No           No  No phone service             DSL
# 4  Female      No         No          Yes                No     Fiber optic
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No          No          No
# 1            Yes           No              Yes          No          No
# 2            Yes          Yes               No          No          No
# 3            Yes           No              Yes         Yes          No
# 4             No           No               No          No          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
all_categorical_columns['gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 7038      Male
# 7039    Female
# 7040    Female
# 7041      Male
# 7042      Male
# Name: gender, Length: 7043, dtype: object

# %%
encoder.fit(all_categorical_columns['gender'])
# Out:
# LabelEncoder()

# %%
for column_name in all_categorical_columns:
    print(column_name)
# Out:
# gender
# Partner
# Dependents
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# TotalCharges

# %%
for column_name in all_categorical_columns:
    features[column_name] = encoder.fit_transform( all_categorical_columns[column_name])

# %%
all_categorical_columns.head()
# Out:
#    gender Partner Dependents PhoneService     MultipleLines InternetService  \
# 0  Female     Yes         No           No  No phone service             DSL
# 1    Male      No         No          Yes                No             DSL
# 2    Male      No         No          Yes                No             DSL
# 3    Male      No         No           No  No phone service             DSL
# 4  Female      No         No          Yes                No     Fiber optic
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No          No          No
# 1            Yes           No              Yes          No          No
# 2            Yes          Yes               No          No          No
# 3            Yes           No              Yes         Yes          No
# 4             No           No               No          No          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
features.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %% [markdown]
# # DATA SPLITTING

# %%
print(f"Our data contains {len(features)} before splitting")
# Out:
# Our data contains 7043 before splitting

# %%
from sklearn.model_selection import train_test_split

# %%
train_data , test_data = train_test_split(features, test_size = 0.2)

# %%
len(train_data)
# Out:
# 5634

# %%
0.8 * len(features)
# Out:
# 5634.400000000001

# %%
0.2 * len(features)
# Out:
# 1408.6000000000001

# %%
len(train_data) + len(test_data) == len(features)
# Out:
# True

# %%
feature_train_data, feature_test_data, label_train_data, label_test_data = train_test_split(features, labels, test_size = 0.2, random_state = 42)

# %%
len(feature_train_data) == len(label_train_data)
# Out:
# True

# %% [markdown]
# # x -----> features
# #  y  -------> labels

# %%
xtrain, xtest, ytrain, ytest = train_test_split(features, labels, test_size = 0.2, random_state = 42)

# %%
xtrain.head()
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 2142       0              0        0           1      21             1
# 1623       0              0        0           0      54             1
# 6074       1              0        1           0       1             0
# 1362       1              0        0           0       4             1
# 6754       1              0        0           1       0             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 2142              0                0               2             0
# 1623              2                1               0             2
# 6074              1                0               0             0
# 1362              0                1               0             0
# 6754              2                0               2             2
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %%
xtest.head()
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 185        0              0        1           0       1             0
# 2715       1              0        0           0      41             1
# 3825       0              0        1           1      52             1
# 1807       0              0        0           0       1             1
# 132        1              0        0           0      67             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 185               1                0               0             0
# 2715              2                2               1             1
# 3825              0                2               1             1
# 1807              0                1               0             0
# 132               0                0               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %% [markdown]
# # Train the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(random_state = 42)

# %%
model.fit(xtrain, ytrain)
# Out:
# C:\Users\kweku Bediako\Downloads\New folder\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %% [markdown]
# #  the total iterations were reached so it suggests that we increase the number of iterations. When you check it the max is 100 but the other one also talksaboy scaling of data which wasn't done .
# # Betterstill we can predict the model
# ## For model evaluation;

# %%
predictions = model.predict(xtest)

# %%
predictions
# Out:
# array(['Yes', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
ytest.values
# Out:
# array(['Yes', 'No', 'No', ..., 'No', 'No', 'Yes'], dtype=object)

# %%
#  this is a bit dicey

# %%
    from sklearn.metrics import classification_report, confusion_matrix

# %%
report = classification_report(ytest, predictions)
matrix = confusion_matrix(ytest, predictions)

# %%
print("Classification Report: \n", report)
print("Confusion Matrix: \n", matrix)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#           No       0.85      0.91      0.88      1036
#          Yes       0.68      0.56      0.61       373
#
#     accuracy                           0.81      1409
#    macro avg       0.77      0.73      0.75      1409
# weighted avg       0.81      0.81      0.81      1409
#
# Confusion Matrix:
#  [[938  98]
#  [164 209]]

# %%
# we have 81% accuracy out of the 1409 records we have
#  the overall prediction for yes is 85%

# %%
sns.heatmap(matrix, annot = True, fmt='g')
plt.xlabel("Actual values")
plt.ylabel("Predictions")
# Out:
# Text(50.722222222222214, 0.5, 'Predictions')

# %% [markdown]
# # LETS SEE IF DATA SCALING WILL IMPROVE MODEL PERFORMANCE

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
xtrain_scaled = scaler.fit_transform(xtrain)

# %%
xtest_scaled = scaler.transform(xtest)

# %%
model = LogisticRegression(random_state = 42)
model.fit(xtrain_scaled, ytrain)
# Out:
# LogisticRegression(random_state=42)

# %%
# now data is trained successfully

# %%
predictions = model.predict(xtest_scaled)

# %%
report = classification_report(ytest, predictions, digits = 5)
matrix = confusion_matrix(ytest, predictions)
print("Classification Report: \n", report)
print("Confusion Matrix: \n", matrix)
sns.heatmap(matrix, annot = True, fmt='g')
plt.xlabel("Actual values")
plt.ylabel("Predictions")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#           No    0.85018   0.90927   0.87873      1036
#          Yes    0.68771   0.55496   0.61424       373
#
#     accuracy                        0.81547      1409
#    macro avg    0.76894   0.73211   0.74649      1409
# weighted avg    0.80717   0.81547   0.80871      1409
#
# Confusion Matrix:
#  [[942  94]
#  [166 207]]
# Text(50.722222222222214, 0.5, 'Predictions')

# %%
weights = {'No':1, 'Yes':4} 
model = LogisticRegression(random_state = 42, class_weight=weights  )
model.fit(xtrain_scaled, ytrain)
predictions = model.predict(xtest_scaled)
report = classification_report(ytest, predictions, digits = 5)
matrix = confusion_matrix(ytest, predictions)
print("Classification Report: \n", report)
print("Confusion Matrix: \n", matrix)
sns.heatmap(matrix, annot = True, fmt='g')
plt.xlabel("Actual values")
plt.ylabel("Predictions")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#           No    0.93508   0.65347   0.76932      1036
#          Yes    0.47591   0.87399   0.61626       373
#
#     accuracy                        0.71185      1409
#    macro avg    0.70550   0.76373   0.69279      1409
# weighted avg    0.81353   0.71185   0.72880      1409
#
# Confusion Matrix:
#  [[677 359]
#  [ 47 326]]
# Text(50.722222222222214, 0.5, 'Predictions')

# %%
data = pd.read_csv("C:\\Users\kweku Bediako\\Downloads\\Customer-Churn.csv")

# %%
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'],errors='coerce')

# %%
data_cleaned = data.dropna(subset=['TotalCharges'])

# %% [markdown]
# # Visualizing the relationship between the label and key features

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Churn', data = data_cleaned, palette = 'Set2')
plt.title('Distribution of Churn')
plt.show()

# %% [markdown]
# # Monthly Charges Against Churn

# %%
plt.figure(figsize=(20,6))
sns.countplot(data = data_cleaned, x='MonthlyCharges', hue = 'Churn', dodge =True)
plt.title('Churn against MonthlyCharges')
plt.xlabel('MonthlyCharges')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Tenure Against Churn

# %%
plt.figure(figsize=(20,6))
sns.countplot(data = data_cleaned, x='tenure', hue = 'Churn', dodge =True)
plt.title('Churn against tenure')
plt.xlabel('tenure (months)')
plt.ylabel('Count')
plt.show()

# %%
print(data_cleaned.columns)
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
plt.figure(figsize=(20,6))
sns.histplot(data = data_cleaned['tenure'], kde = True, color = 'orange')
plt.title('Distribution of Tenure')
plt.xlabel('Tenure (months)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Downloads\New folder\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tenure'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[143], line 9
#       1 #plt.figure(figsize=(15,6))
# ...

# %% [markdown]
# # Bivariate Analysis of Internet Services Against Churn

# %%
plt.figure(figsize=(10,6))
sns.countplot(data = data_cleaned, x='InternetService', hue = 'Churn', dodge =True)
plt.title('Internet Services Vs Churn')
plt.xlabel('InternetService Types')
plt.show()

# %% [markdown]
# # Multivariate Analysis of Contract Type, Monthly Charges and Churn

# %%
sns.pairplot(data_cleaned[['Contract' ,'MonthlyCharges','Churn']], hue = 'Churn')
plt.title('Pairplot of Contract Type, MonthlyCharges and Churn')
plt.show()
# Out:
# C:\Users\kweku Bediako\Downloads\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

data_cleaned = pd.DataFrame({
    'Contract': ['Month-to-month', 'One year', 'Two year'],
    'MonthlyCharges': [29.99, 19.99, 24.99],
    'Churn': ['Yes', 'No', 'Yes']
})

# Convert categorical 'Contract' to one-hot encoded columns
data_encoded = pd.get_dummies(data_cleaned, columns=['Contract'], drop_first=True)

# Convert 'Churn' to a binary variable
data_encoded['Churn_Yes'] = data_encoded['Churn'].map({'Yes': 1, 'No': 0})

# Drop the original 'Churn' column
data_encoded = data_encoded.drop(columns=['Churn'])

# Define features and target
X = data_encoded.drop(columns=['Churn_Yes'])
y = data_encoded['Churn_Yes']

# Initialize and apply StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Output shapes of the split datasets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (2, 3)
# X_test shape: (1, 3)
# y_train shape: (2,)
# y_test shape: (1,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay


log_reg = LogisticRegression(random_state=42)
log_reg.fit(X_train, y_train)
y_pred_log_reg = log_reg.predict(X_test)
cm_log_reg = confusion_matrix(y_test, y_pred_log_reg)
ConfusionMatrixDisplay(cm_log_reg).plot()
plt.title('Logistic Regression Confusion Matrix')
plt.show()

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)
cm_rf = confusion_matrix(y_test, y_pred_rf)
ConfusionMatrixDisplay(cm_rf).plot()
plt.title('Random Forest Confusion Matrix')
plt.show()

# %%
svm_model = SVC(random_state=42)
svm_model.fit(X_train, y_train)
y_pred_svm = svm_model.predict(X_test)
cm_svm = confusion_matrix(y_test, y_pred_svm)
ConfusionMatrixDisplay(cm_svm).plot()
plt.title('SVM Confusion Matrix')
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=2)  
knn_model.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)


c_knn = confusion_matrix(y_test, y_pred_knn)


ConfusionMatrixDisplay(confusion_matrix=c_knn).plot()
plt.title('KNN Confusion Matrix')
plt.show()
